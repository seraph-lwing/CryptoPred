# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp310-cp310-win_amd64.whl (153 kB)
#      ------------------------------------ 153.1/153.1 kB 326.1 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in c:\software\envs\cryptopred\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\software\envs\cryptopred\lib\site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: matplotlib in c:\software\envs\cryptopred\lib\site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\software\envs\cryptopred\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\software\envs\cryptopred\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\software\envs\cryptopred\lib\site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\software\envs\cryptopred\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\software\envs\cryptopred\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\software\envs\cryptopred\lib\site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\software\envs\cryptopred\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\software\envs\cryptopred\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from collections import Counter
from wordcloud import WordCloud

# %%
tweets = pd.read_csv('tweets/crypto_10k_tweets_(2021_2022Nov).csv', lineterminator='\n',parse_dates=True).drop('Unnamed: 0', axis=1)
tweets.head()
# Out:
#                         Date         Username  \
# 0  2022-11-30 11:53:21+00:00   0xEthereumYoda
# 1  2022-11-30 11:53:21+00:00  Lawrenc32984128
# 2  2022-11-30 11:53:21+00:00  NITESHP55784410
# 3  2022-11-30 11:53:20+00:00          817coin
# 4  2022-11-30 11:53:18+00:00        slamtoken
#
#                                              Content  \
# 0  #Ethereum price update: \n\n#ETH $1269.23 USD\...
# 1  @mtmalinen @ecb Do well to understand that eve...
# 2  Kayla #Ethereum Harold #世界杯 Egbert #百家乐 Lavern...
# 3  #Bitcoin https://t.co/2koLlCvCri https://t.co/...
# 4  Yesterday we made a 3,000 SLAM buyback and loc...
#
#                                                  URL  \
# 0  https://twitter.com/0xEthereumYoda/status/1597...
# 1  https://twitter.com/Lawrenc32984128/status/159...
# 2  https://twitter.com/NITESHP55784410/status/159...
# 3  https://twitter.com/817coin/status/15979217174...
# 4  https://twitter.com/slamtoken/status/159792171...
#
#                                           Hashtags\r
# 0  ['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin...
# 1                                          ['BTC']\r
# 2              ['Ethereum', '世界杯', '百家乐', '世界杯买球']\r
# 3                                      ['Bitcoin']\r
# 4                      ['slamtoken', 'bnb', 'bsc']\r

# %%
tweets.head()
# Out:
#                         Date         Username  \
# 0  2022-11-30 11:53:21+00:00   0xEthereumYoda
# 1  2022-11-30 11:53:21+00:00  Lawrenc32984128
# 2  2022-11-30 11:53:21+00:00  NITESHP55784410
# 3  2022-11-30 11:53:20+00:00          817coin
# 4  2022-11-30 11:53:18+00:00        slamtoken
#
#                                              Content  \
# 0  #Ethereum price update: \n\n#ETH $1269.23 USD\...
# 1  @mtmalinen @ecb Do well to understand that eve...
# 2  Kayla #Ethereum Harold #世界杯 Egbert #百家乐 Lavern...
# 3  #Bitcoin https://t.co/2koLlCvCri https://t.co/...
# 4  Yesterday we made a 3,000 SLAM buyback and loc...
#
#                                                  URL  \
# 0  https://twitter.com/0xEthereumYoda/status/1597...
# 1  https://twitter.com/Lawrenc32984128/status/159...
# 2  https://twitter.com/NITESHP55784410/status/159...
# 3  https://twitter.com/817coin/status/15979217174...
# 4  https://twitter.com/slamtoken/status/159792171...
#
#                                           Hashtags\r
# 0  ['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin...
# 1                                          ['BTC']\r
# 2              ['Ethereum', '世界杯', '百家乐', '世界杯买球']\r
# 3                                      ['Bitcoin']\r
# 4                      ['slamtoken', 'bnb', 'bsc']\r

# %%
tweets.describe()
# Out:
#                              Date        Username              Content  \
# count                       10086           10086                10000
# unique                       6057            5683                 9767
# top     2022-11-30 10:00:01+00:00  0xEthereumYoda  @TrustWallet 4 #BNB
# freq                           18             134                   17
#
#                                                       URL     Hashtags\r
# count                                                9914          10458
# unique                                               9914           4569
# top     https://twitter.com/0xEthereumYoda/status/1597...  ['Bitcoin']\r
# freq                                                    1            891

# %%
tweets.isna().sum()
# Out:
# Date          372
# Username      372
# Content       458
# URL           544
# Hashtags\r      0
# dtype: int64

# %%
print(f'The original data shape:{tweets.shape}')
clean_tweets = tweets.dropna(subset=['Date','Content','URL'],axis=0)
print(f'The datacleaning shape:{clean_tweets.shape}')
# Out:
# The original data shape:(10458, 5)
# The datacleaning shape:(9914, 5)

# %%
clean_tweets.isna().sum()
# Out:
# Date          0
# Username      0
# Content       0
# URL           0
# Hashtags\r    0
# dtype: int64

# %%
clean_tweets[clean_tweets['Content'].isna()]
# Out:
# Empty DataFrame
# Columns: [Date, Username, Content, URL, Hashtags
# ]
# Index: []

# %%
clean_tweets.sample(10)
# Out:
#                             Date        Username  \
# 3081   2022-11-30 11:07:08+00:00     letecho_com
# 377    2022-11-30 11:47:44+00:00     missbubwin_
# 6448   2022-11-30 10:17:07+00:00          Tomcx7
# 3882   2022-11-30 10:58:14+00:00       DobbyToyz
# 2708   2022-11-30 11:13:04+00:00       Makiproms
# 7115   2022-11-30 10:05:32+00:00   stereotypes__
# 6227   2022-11-30 10:21:21+00:00       cripto_on
# 4964   2022-11-30 10:40:57+00:00    bruindesimon
# 237    2022-11-30 11:49:52+00:00        247robby
# 10377  2022-11-30 09:17:38+00:00  Crypto_xiaoxin
#
#                                                  Content  \
# 3081   #bnb #BNB [2022/11/30 20:06:56]\n値段：41,843¥\n時...
# 377          @UnidefTimes @John_Barlowe $BNB #cryptonews
# 6448   https://t.co/MRBnOw0zSh #Bitcoin #NFT #opensa ...
# 3882   Dobby Toyz ETH Rising ✨ \n\n🔗 https://t.co/yab...
# 2708   A single tree can absorb as much as 22 kilos o...
# 7115   Sking in the Opensea...🏂🎿🌊\n\n#blockchain #ski...
# 6227   Whale Alert in #TRON: $USDT 4859950 ($ 4,885,9...
# 4964   📢Fascinating shapes of mushrooms - autumn arbo...
# 237    [3412] #dtv The VERY best #Bitcoin (#Miner) th...
# 10377  我们需要关心的是2023美g是否会经济衰退，，如果陷入的话美联储在衰退中是否会像2020年的...
#
#                                                      URL  \
# 3081   https://twitter.com/letecho_com/status/1597910...
# 377    https://twitter.com/missbubwin_/status/1597920...
# 6448   https://twitter.com/Tomcx7/status/159789750758...
# 3882   https://twitter.com/DobbyToyz/status/159790785...
# 2708   https://twitter.com/Makiproms/status/159791158...
# 7115   https://twitter.com/stereotypes__/status/15978...
# 6227   https://twitter.com/cripto_on/status/159789857...
# 4964   https://twitter.com/bruindesimon/status/159790...
# 237    https://twitter.com/247robby/status/1597920845...
# 10377  https://twitter.com/Crypto_xiaoxin/status/1597...
#
#                                               Hashtags\r
# 3081   ['bnb', 'BNB', 'cyptocurrency', '仮想通貨', 'ビットコイ...
# 377                                     ['cryptonews']\r
# 6448   ['Bitcoin', 'NFT', 'opensa', 'Satoshi', 'Twitt...
# 3882   ['NFT', 'NFTs', 'NFTCommunity', 'Opensea', 'NF...
# 2708   ['TechTreesSDG', 'TechTrees', 'BNB', 'BSC', 'B...
# 7115   ['blockchain', 'skier', 'common', 'medium', 'p...
# 6227                  ['TRON', 'WhaleAlert', 'crypto']\r
# 4964             ['crypto', 'referral', 'earn', 'btc']\r
# 237    ['dtv', 'Bitcoin', 'Miner', 'silent', 'here', ...
# 10377                                   ['BTC', 'ETH']\r

# %%
clean_tweets.index = clean_tweets['Date']
clean_tweets
# Out:
#                                                 Date         Username  \
# Date
# 2022-11-30 11:53:21+00:00  2022-11-30 11:53:21+00:00   0xEthereumYoda
# 2022-11-30 11:53:21+00:00  2022-11-30 11:53:21+00:00  Lawrenc32984128
# 2022-11-30 11:53:21+00:00  2022-11-30 11:53:21+00:00  NITESHP55784410
# 2022-11-30 11:53:20+00:00  2022-11-30 11:53:20+00:00          817coin
# 2022-11-30 11:53:18+00:00  2022-11-30 11:53:18+00:00        slamtoken
# ...                                              ...              ...
# 2022-11-30 09:16:43+00:00  2022-11-30 09:16:43+00:00   tecniaofficial
# 2022-11-30 09:16:41+00:00  2022-11-30 09:16:41+00:00  BullshitTrader_
# 2022-11-30 09:16:40+00:00  2022-11-30 09:16:40+00:00         rektBart
# 2022-11-30 09:16:39+00:00  2022-11-30 09:16:39+00:00   kamalalshehabi
# 2022-11-30 09:16:38+00:00  2022-11-30 09:16:38+00:00        jimmyvs24
#
#                                                                      Content  \
# Date
# 2022-11-30 11:53:21+00:00  #Ethereum price update: \n\n#ETH $1269.23 USD\...
# 2022-11-30 11:53:21+00:00  @mtmalinen @ecb Do well to understand that eve...
# 2022-11-30 11:53:21+00:00  Kayla #Ethereum Harold #世界杯 Egbert #百家乐 Lavern...
# 2022-11-30 11:53:20+00:00  #Bitcoin https://t.co/2koLlCvCri https://t.co/...
# 2022-11-30 11:53:18+00:00  Yesterday we made a 3,000 SLAM buyback and loc...
# ...                                                                      ...
# 2022-11-30 09:16:43+00:00  Digital Rupee or e-Rupee is a form of digital ...
# 2022-11-30 09:16:41+00:00  In bear market, short every pump n dca every u...
# 2022-11-30 09:16:40+00:00  Take that high and I’m max short #btc https://...
# 2022-11-30 09:16:39+00:00  في خطة التوسع حول العالم، باينانس تستحوذ على م...
# 2022-11-30 09:16:38+00:00  The 15m #bitcoin just went into self custody h...
#
#                                                                          URL  \
# Date
# 2022-11-30 11:53:21+00:00  https://twitter.com/0xEthereumYoda/status/1597...
# 2022-11-30 11:53:21+00:00  https://twitter.com/Lawrenc32984128/status/159...
# 2022-11-30 11:53:21+00:00  https://twitter.com/NITESHP55784410/status/159...
# 2022-11-30 11:53:20+00:00  https://twitter.com/817coin/status/15979217174...
# 2022-11-30 11:53:18+00:00  https://twitter.com/slamtoken/status/159792171...
# ...                                                                      ...
# 2022-11-30 09:16:43+00:00  https://twitter.com/tecniaofficial/status/1597...
# 2022-11-30 09:16:41+00:00  https://twitter.com/BullshitTrader_/status/159...
# 2022-11-30 09:16:40+00:00  https://twitter.com/rektBart/status/1597882292...
# 2022-11-30 09:16:39+00:00  https://twitter.com/kamalalshehabi/status/1597...
# 2022-11-30 09:16:38+00:00  https://twitter.com/jimmyvs24/status/159788228...
#
#                                                                   Hashtags\r
# Date
# 2022-11-30 11:53:21+00:00  ['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin...
# 2022-11-30 11:53:21+00:00                                          ['BTC']\r
# 2022-11-30 11:53:21+00:00              ['Ethereum', '世界杯', '百家乐', '世界杯买球']\r
# 2022-11-30 11:53:20+00:00                                      ['Bitcoin']\r
# 2022-11-30 11:53:18+00:00                      ['slamtoken', 'bnb', 'bsc']\r
# ...                                                                      ...
# 2022-11-30 09:16:43+00:00  ['tias', 'tecnia', 'rupee', 'digital', 'digita...
# 2022-11-30 09:16:41+00:00                     ['btc', 'bitcoin', 'crypto']\r
# 2022-11-30 09:16:40+00:00                                          ['btc']\r
# 2022-11-30 09:16:39+00:00                  ['crypto', 'binance', 'كريبتو']\r
# 2022-11-30 09:16:38+00:00                                      ['bitcoin']\r
#
# [9914 rows x 5 columns]

# %%
clean_tweets.sample(10)
# Out:
#                                                 Date         Username  \
# Date
# 2022-11-30 10:01:45+00:00  2022-11-30 10:01:45+00:00  Cryptoc95295747
# 2022-11-30 09:26:29+00:00  2022-11-30 09:26:29+00:00   0xEthereumYoda
# 2022-11-30 10:14:31+00:00  2022-11-30 10:14:31+00:00  comristorazione
# 2022-11-30 09:22:04+00:00  2022-11-30 09:22:04+00:00      joe1_elijah
# 2022-11-30 11:20:29+00:00  2022-11-30 11:20:29+00:00     HeverCastroB
# 2022-11-30 11:40:12+00:00  2022-11-30 11:40:12+00:00          tr71765
# 2022-11-30 11:30:58+00:00  2022-11-30 11:30:58+00:00         ZWoxvall
# 2022-11-30 09:40:00+00:00  2022-11-30 09:40:00+00:00     MarioRomeroX
# 2022-11-30 10:40:02+00:00  2022-11-30 10:40:02+00:00     Bitcoin10min
# 2022-11-30 10:30:36+00:00  2022-11-30 10:30:36+00:00    Ethereumhyper
#
#                                                                      Content  \
# Date
# 2022-11-30 10:01:45+00:00  FTX gaat betalingen naar werknemers hervatten ...
# 2022-11-30 09:26:29+00:00  #Ethereum price update: \n\n#ETH $1266.33 USD\...
# 2022-11-30 10:14:31+00:00  La prima pizza al mondo certificata #blockchai...
# 2022-11-30 09:22:04+00:00  Free #NFT giveaway 👑 48 hours ⏰\n\nDrop your $...
# 2022-11-30 11:20:29+00:00  Una cosa es que el #bitcoin se pueda usar como...
# 2022-11-30 11:40:12+00:00  Kennedy Edison Gavin Scott #BNB #体彩 Elroy Bert...
# 2022-11-30 11:30:58+00:00  Feels like the worlds is in need of a regulate...
# 2022-11-30 09:40:00+00:00  The #blockchain is still in construction and i...
# 2022-11-30 10:40:02+00:00  $16882.78 | €16298.85 | ¥125000.00 | £14057.10...
# 2022-11-30 10:30:36+00:00  Cuzz Cuzz -  F Da City Up is now playing on ht...
#
#                                                                          URL  \
# Date
# 2022-11-30 10:01:45+00:00  https://twitter.com/Cryptoc95295747/status/159...
# 2022-11-30 09:26:29+00:00  https://twitter.com/0xEthereumYoda/status/1597...
# 2022-11-30 10:14:31+00:00  https://twitter.com/comristorazione/status/159...
# 2022-11-30 09:22:04+00:00  https://twitter.com/joe1_elijah/status/1597883...
# 2022-11-30 11:20:29+00:00  https://twitter.com/HeverCastroB/status/159791...
# 2022-11-30 11:40:12+00:00  https://twitter.com/tr71765/status/15979184147...
# 2022-11-30 11:30:58+00:00  https://twitter.com/ZWoxvall/status/1597916091...
# 2022-11-30 09:40:00+00:00  https://twitter.com/MarioRomeroX/status/159788...
# 2022-11-30 10:40:02+00:00  https://twitter.com/Bitcoin10min/status/159790...
# 2022-11-30 10:30:36+00:00  https://twitter.com/Ethereumhyper/status/15979...
#
#                                                                   Hashtags\r
# Date
# 2022-11-30 10:01:45+00:00  ['Bitcoin', 'Bitcoinnieuws', 'Bitcoinnl', 'cry...
# 2022-11-30 09:26:29+00:00  ['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin...
# 2022-11-30 10:14:31+00:00                  ['blockchain', 'pizza', 'food']\r
# 2022-11-30 09:22:04+00:00  ['NFT', 'NFTCommunity', 'NFTdrop', 'NFTs', 'NF...
# 2022-11-30 11:20:29+00:00                                      ['bitcoin']\r
# 2022-11-30 11:40:12+00:00                                    ['BNB', '体彩']\r
# 2022-11-30 11:30:58+00:00  ['ftx', 'usdt', 'usdc', 'crypto', 'scams', 'fr...
# 2022-11-30 09:40:00+00:00                                   ['blockchain']\r
# 2022-11-30 10:40:02+00:00    ['bitcoinprice', 'cryptocurrency', 'bitcoin']\r
# 2022-11-30 10:30:36+00:00  ['Listen', 'Earn', 'Crypto', 'NFTCommunity', '...

# %% [markdown]
# ## Cleaning the text

# %%
def clean_hashtags(string):
    replacements = [
    ("[",""),
    ("]",""),
    ("BITCOIN","BTC"),
    ("ETHEREUM","ETH"),
    ("TETHER","USDT"),
    ("BINANCE","BNB"),
    ("BINANCE COIN","BNB"),
    ("\r",""),
    ("'",""),
    (" ",""),
]
    #print(string)
    for old,new in replacements:
        string= string.strip().upper().replace(old,new).strip()
    return string

# %%
clean_tweets["Hashtags\r"] = clean_tweets["Hashtags\r"].apply(clean_hashtags)
# Out:
# C:\Users\vishwang.dave\AppData\Local\Temp\ipykernel_22584\1088371447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_tweets["Hashtags\r"] = clean_tweets["Hashtags\r"].apply(clean_hashtags)

# %%
hash_df = clean_tweets['Hashtags\r'].str.split(',', expand=True)
clean_tweets = clean_tweets.join(hash_df)

# %%
clean_tweets
# Out:
#                                                 Date         Username  \
# Date
# 2022-11-30 09:16:38+00:00  2022-11-30 09:16:38+00:00        jimmyvs24
# 2022-11-30 09:16:39+00:00  2022-11-30 09:16:39+00:00   kamalalshehabi
# 2022-11-30 09:16:40+00:00  2022-11-30 09:16:40+00:00         rektBart
# 2022-11-30 09:16:41+00:00  2022-11-30 09:16:41+00:00  BullshitTrader_
# 2022-11-30 09:16:43+00:00  2022-11-30 09:16:43+00:00     Cafecrypto41
# ...                                              ...              ...
# 2022-11-30 11:53:21+00:00  2022-11-30 11:53:21+00:00  Lawrenc32984128
# 2022-11-30 11:53:21+00:00  2022-11-30 11:53:21+00:00  Lawrenc32984128
# 2022-11-30 11:53:21+00:00  2022-11-30 11:53:21+00:00  NITESHP55784410
# 2022-11-30 11:53:21+00:00  2022-11-30 11:53:21+00:00  NITESHP55784410
# 2022-11-30 11:53:21+00:00  2022-11-30 11:53:21+00:00  NITESHP55784410
#
#                                                                      Content  \
# Date
# 2022-11-30 09:16:38+00:00  The 15m #bitcoin just went into self custody h...
# 2022-11-30 09:16:39+00:00  في خطة التوسع حول العالم، باينانس تستحوذ على م...
# 2022-11-30 09:16:40+00:00  Take that high and I’m max short #btc https://...
# 2022-11-30 09:16:41+00:00  In bear market, short every pump n dca every u...
# 2022-11-30 09:16:43+00:00  #Crypto trading is in the hands of a few peopl...
# ...                                                                      ...
# 2022-11-30 11:53:21+00:00  @mtmalinen @ecb Do well to understand that eve...
# 2022-11-30 11:53:21+00:00  @mtmalinen @ecb Do well to understand that eve...
# 2022-11-30 11:53:21+00:00  Kayla #Ethereum Harold #世界杯 Egbert #百家乐 Lavern...
# 2022-11-30 11:53:21+00:00  Kayla #Ethereum Harold #世界杯 Egbert #百家乐 Lavern...
# 2022-11-30 11:53:21+00:00  Kayla #Ethereum Harold #世界杯 Egbert #百家乐 Lavern...
#
#                                                                          URL  \
# Date
# 2022-11-30 09:16:38+00:00  https://twitter.com/jimmyvs24/status/159788228...
# 2022-11-30 09:16:39+00:00  https://twitter.com/kamalalshehabi/status/1597...
# 2022-11-30 09:16:40+00:00  https://twitter.com/rektBart/status/1597882292...
# 2022-11-30 09:16:41+00:00  https://twitter.com/BullshitTrader_/status/159...
# 2022-11-30 09:16:43+00:00  https://twitter.com/Cafecrypto41/status/159788...
# ...                                                                      ...
# 2022-11-30 11:53:21+00:00  https://twitter.com/Lawrenc32984128/status/159...
# 2022-11-30 11:53:21+00:00  https://twitter.com/Lawrenc32984128/status/159...
# 2022-11-30 11:53:21+00:00  https://twitter.com/NITESHP55784410/status/159...
# 2022-11-30 11:53:21+00:00  https://twitter.com/NITESHP55784410/status/159...
# 2022-11-30 11:53:21+00:00  https://twitter.com/NITESHP55784410/status/159...
#
#                                                                   Hashtags\r  \
# Date
# 2022-11-30 09:16:38+00:00                                                BTC
# 2022-11-30 09:16:39+00:00                                CRYPTO, BNB, كريبتو
# 2022-11-30 09:16:40+00:00                                                BTC
# 2022-11-30 09:16:41+00:00                                   BTC, BTC, CRYPTO
# 2022-11-30 09:16:43+00:00  CRYPTO, CRYPTO, BTC, BNB, ETH, LUNC, JASMYCOIN...
# ...                                                                      ...
# 2022-11-30 11:53:21+00:00                                                BTC
# 2022-11-30 11:53:21+00:00                                                BTC
# 2022-11-30 11:53:21+00:00                               ETH, 世界杯, 百家乐, 世界杯买球
# 2022-11-30 11:53:21+00:00                               ETH, 世界杯, 百家乐, 世界杯买球
# 2022-11-30 11:53:21+00:00                               ETH, 世界杯, 百家乐, 世界杯买球
#
#                                 0        1        2       3         4  ...  \
# Date                                                                   ...
# 2022-11-30 09:16:38+00:00     BTC     None     None    None      None  ...
# 2022-11-30 09:16:39+00:00  CRYPTO      BNB   كريبتو    None      None  ...
# 2022-11-30 09:16:40+00:00     BTC     None     None    None      None  ...
# 2022-11-30 09:16:41+00:00     BTC      BTC   CRYPTO    None      None  ...
# 2022-11-30 09:16:43+00:00  CRYPTO   CRYPTO      BTC     BNB       ETH  ...
# ...                           ...      ...      ...     ...       ...  ...
# 2022-11-30 11:53:21+00:00     BTC     None     None    None      None  ...
# 2022-11-30 11:53:21+00:00     ETH      世界杯      百家乐   世界杯买球      None  ...
# 2022-11-30 11:53:21+00:00     ETH      ETH      BTC     BTC   ALTCOIN  ...
# 2022-11-30 11:53:21+00:00     BTC     None     None    None      None  ...
# 2022-11-30 11:53:21+00:00     ETH      世界杯      百家乐   世界杯买球      None  ...
#
#                              29    30    31    32    33    34    35    36  \
# Date
# 2022-11-30 09:16:38+00:00  None  None  None  None  None  None  None  None
# 2022-11-30 09:16:39+00:00  None  None  None  None  None  None  None  None
# 2022-11-30 09:16:40+00:00  None  None  None  None  None  None  None  None
# 2022-11-30 09:16:41+00:00  None  None  None  None  None  None  None  None
# 2022-11-30 09:16:43+00:00  None  None  None  None  None  None  None  None
# ...                         ...   ...   ...   ...   ...   ...   ...   ...
# 2022-11-30 11:53:21+00:00  None  None  None  None  None  None  None  None
# 2022-11-30 11:53:21+00:00  None  None  None  None  None  None  None  None
# 2022-11-30 11:53:21+00:00  None  None  None  None  None  None  None  None
# 2022-11-30 11:53:21+00:00  None  None  None  None  None  None  None  None
# 2022-11-30 11:53:21+00:00  None  None  None  None  None  None  None  None
#
#                              37    38
# Date
# 2022-11-30 09:16:38+00:00  None  None
# 2022-11-30 09:16:39+00:00  None  None
# 2022-11-30 09:16:40+00:00  None  None
# 2022-11-30 09:16:41+00:00  None  None
# 2022-11-30 09:16:43+00:00  None  None
# ...                         ...   ...
# 2022-11-30 11:53:21+00:00  None  None
# 2022-11-30 11:53:21+00:00  None  None
# 2022-11-30 11:53:21+00:00  None  None
# 2022-11-30 11:53:21+00:00  None  None
# 2022-11-30 11:53:21+00:00  None  None
#
# [23332 rows x 44 columns]

# %%
tags=list(range(39))
clean_tweets[[0,1]].value_counts()
# Out:
# 0              1
# BTC             BTC        806
# ETH             ETH        539
# BTC             ETH        431
#                 CRYPTO     297
# CRYPTO          BTC        257
#                           ...
# CATVILLS        BSC          1
# BNB             SEBC         1
# SARCASMMASTER   NFT          1
# SASA            BIST100      1
# STX             CRYPTO       1
# Length: 3024, dtype: int64

# %%
final_count = Counter()
for col in tags:
    final_count = Counter(clean_tweets[col]) + final_count
print(type(final_count))
# Out:
# <class 'collections.Counter'>

# %%
sum(final_count.values())/len(final_count.values())
# Out:
# 139.819913952059

# %%
def removeInfrequent(dictionary):
    d = dict()
    for key,values in  dictionary.items():
        if values > 100:
            d[key] = values
    return d
frequent_tags = removeInfrequent(final_count)

# %%
frequent_tags.keys()
# Out:
# dict_keys([None, ' NFT', ' DEFI', ' BCH', ' CRYPTO', ' USDT', ' ADA', ' BTC', ' CRYPTONEWS', ' NEWS', ' DOGE', ' FOREX', ' ELONMUSK', ' METAVERSE', ' TRADING', ' CRYPTOTRADING', ' BNB', ' WEB3', ' CRYPTOCURRENCY', ' AI', ' SHIB', ' MATIC', ' NFTCOMMUNITY', ' NFTART', ' ETH', ' POLYGON', ' NFTS', ' BLOCKCHAIN', ' 仮想通貨', ' NFTSHILL', ' ALTCOIN', ' BTCUSD', ' SOLANA', ' FREEMINT', ' AVAX', ' SOL', ' BSC', ' EXCHANGE', ' RBXS', ' USDC', ' FINTECH', ' XRP', ' MONEY', ' NFTCOLLECTOR', ' NFTDROP', ' GAMEFI', ' CRYPTOMARKET', ' NFTSALES', ' NFTARTIST', ' NFTPROJECT', ' NFTBUY', ' 1000XGEM', ' CRYPTOCURENCY', ' OPENSEA', ' ALTCOINS', ' AIRDROP', ' FTX', ' ART', ' NEURALINK', ' GOLD', ' NFTCOLLECTORS', ' CRYPTOCURRENCIES', ' LTC', ' NFTPROJECTS', ' DOGECOIN', ' GIVEAWAY', ' FTM', ' NFTJAPAN', ' 1000X', ' CMC', ' AIRDROPS', ' NFTCRYPTO', ' CARDANO', ' RIPPLE', ' 世界杯', ' TRU', ' 世界杯买球', ' 卡塔尔世界杯', ' 世界杯投注', ' WHALEALERT', 'BTC', 'CRYPTO', 'NFT', 'USDC', 'NEURALINK', 'ETH', 'CRYPTONEWS', 'BNB', 'BNBCOIN', 'DEFI', 'BLOCKCHAIN', 'CRYPTOCURRENCY', 'WEB3', 'FTX', 'NFTGIVEAWAY', 'EVERRISE', '30MCANDLESTA4CRYPTO', 'BUSD'])

# %%
frequent_tags.pop(None)
# Out:
# 809600

# %%
len(frequent_tags.keys())
# Out:
# 67

# %%
key = 'BTC'
value = 10
l=key*value
l
# Out:
# 'BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC'

# %%
# create a single list with words as frequency number of times
def textFromdict(d):
    """
    takes in a frequency dictionary and creates a list
    """
    l = [key for i in range(value) for key,value in d.items()]
    return l
list_words = listFromdict(frequent_tags)
list_words

# %%
#tuples = [tuple(x) for x in df.values]
wordcloud = WordCloud()
wordcloud.generate_from_frequencies(frequent_tags)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## as we can see there is a lot of NFT

# %%
del final_count[None]

# %%
final_count
# Out:
# Counter({" 'NFT'": 1522,
#          " 'DEFI'": 471,
#          " 'CRV'": 22,
#          " 'BTT'": 8,
#          " 'BCH'": 108,
#          " 'DAO'": 60,
#          " 'APE'": 62,
#          " 'VOLTINU'": 3,
#          " 'SOLANAGIVEAWAY'": 12,
#          " 'CRYPTO'": 5839,
#          " 'BONE'": 10,
#          " 'AVALANCHE'": 13,
#          " 'CPI'": 13,
#          " 'COIN'": 40,
#          " 'WAGMI'": 12,
#          " 'DOMAINFORSALE'": 5,
#          " '美聯儲'": 2,
#          " 'USDT'": 180,
#          " 'USA'": 10,
#          " 'IXP'": 2,
#          " 'OTKAR'": 2,
#          " 'MANA'": 19,
#          " 'STARTUP'": 44,
#          " '區塊鏈'": 13,
#          " 'CHZ'": 20,
#          " 'US'": 7,
#          " 'LUNC'": 63,
#          " 'OPTIMISM'": 6,
#          " 'SNICA'": 3,
#          " 'USD'": 33,
#          " 'ALGO'": 19,
#          " 'BUSINESS'": 100,
#          " 'FINANCE'": 66,
#          " '加密貨幣'": 6,
#          " 'ADA'": 225,
#          " 'CISO'": 2,
#          " 'AMERICA'": 6,
#          " 'SHIBA'": 88,
#          " 'DYDX'": 4,
#          " 'BTC'": 7144,
#          " 'CRYPTONEWS'": 1504,
#          " 'NAMING'": 1,
#          " 'STOCK'": 17,
#          " 'NEW'": 10,
#          " '跟單'": 4,
#          " 'XYZ'": 9,
#          " 'NEWS'": 161,
#          " 'CTO'": 2,
#          " 'DOGE'": 363,
#          " 'WAIFER'": 2,
#          " 'GMX'": 49,
#          " 'YEOTK'": 6,
#          " 'BULLRUN'": 30,
#          " 'NAMES'": 1,
#          " 'FOREX'": 142,
#          " 'FOREXTRADING'": 36,
#          " 'OPTIONBUYING'": 1,
#          " '幣圈分析'": 2,
#          " 'OTC'": 6,
#          " 'HABER'": 10,
#          " 'CIO'": 2,
#          " 'TESLA'": 15,
#          " 'BABYDOGE'": 25,
#          " 'GIVEAWAYS'": 42,
#          " 'KERVN'": 2,
#          " 'NAME'": 1,
#          " 'OPTIONS'": 1,
#          " '幣圈知識'": 2,
#          " 'IPO'": 4,
#          " 'COINBASE'": 92,
#          " 'DATASCIENTIST'": 6,
#          " 'ELONMUSK'": 133,
#          " 'AL'": 1,
#          " 'METAVERSE'": 473,
#          " 'KLEE'": 2,
#          " 'S'": 1,
#          " 'DOGELON'": 16,
#          " 'EARNDOGE'": 1,
#          " 'LUNA'": 60,
#          " 'MOBTL'": 3,
#          " 'OSMEN'": 2,
#          " 'STRAX'": 2,
#          " 'WAXP'": 2,
#          " 'ETHERIUM'": 50,
#          " 'BRANDS'": 1,
#          " 'TRADING'": 441,
#          " 'CURRENCYTRADING'": 3,
#          " 'INDIAN'": 1,
#          " 'FIFAWORLDCUPQATAR2022'": 52,
#          " '幣'": 2,
#          " 'ICO'": 74,
#          " 'VITALIK'": 2,
#          " 'IOT'": 13,
#          " 'I'": 7,
#          " 'AERGO'": 1,
#          " 'AUTONOMOUSVEHICLES'": 1,
#          " 'MVL'": 1,
#          " 'VVS'": 13,
#          " 'PULSECHAIN'": 22,
#          " 'FUTUREOFWORK'": 3,
#          " 'WORLDCUP'": 27,
#          " 'CINU'": 1,
#          " 'IOS'": 3,
#          " 'KONKA'": 3,
#          " 'ATATP'": 2,
#          " 'MLK'": 3,
#          " 'GMT'": 5,
#          " 'ETHER'": 17,
#          " 'BRAND'": 7,
#          " 'DXY'": 16,
#          " 'CRYPTOTRADING'": 345,
#          " 'ECONOMY'": 7,
#          " 'BNB'": 2468,
#          " '元宇宙'": 10,
#          " 'LUFFY'": 13,
#          " 'WEB3'": 748,
#          " 'DEEPLEARNING'": 11,
#          " 'ERC20'": 25,
#          " 'INVESTINGTIPS'": 19,
#          " 'STORJ'": 4,
#          " 'ETHW'": 27,
#          " 'CX'": 2,
#          " 'CRYPTOCURRENCY'": 2358,
#          " 'MXC'": 1,
#          " 'LBRY'": 2,
#          " 'MIATK'": 3,
#          " 'SELVA'": 5,
#          " 'BAT'": 19,
#          " 'BORA'": 19,
#          " 'BRANDNAME'": 5,
#          " 'AI'": 269,
#          " 'FIAT'": 6,
#          " 'MFERS'": 8,
#          " 'MAMA2022'": 8,
#          " 'BUSSINESS'": 1,
#          " 'BYBIT'": 83,
#          " 'SHIB'": 132,
#          " '100DAYSOFCODE'": 31,
#          " 'CEEK'": 5,
#          " 'SIGNALS'": 31,
#          " '3RDCUBE'": 3,
#          " 'ИНВЕСТИЦИИ'": 1,
#          " 'MATIC'": 152,
#          " 'CLOUDCOMPUTING'": 3,
#          " 'NFTCOMMUNITY'": 595,
#          " 'BEP20'": 4,
#          " 'INVESTING'": 59,
#          " 'TONIC'": 13,
#          " 'ENTREPRENEUR'": 14,
#          " 'LUSTIG'": 2,
#          " 'NFTART'": 435,
#          " '美女'": 1,
#          " 'CUSTSERV'": 1,
#          " 'TRADERJOE'": 2,
#          " 'LOOKS'": 1,
#          " 'AAPL'": 8,
#          " 'ELITE'": 3,
#          " 'MEDTR'": 2,
#          " 'MTL'": 2,
#          " 'ETH'": 4341,
#          " 'POLYGON'": 263,
#          " 'DOMAINING'": 5,
#          " 'SONDAKIKA'": 4,
#          " 'LOVE'": 3,
#          " 'MAFX'": 1,
#          " 'CURRENTAFFAIRS'": 1,
#          " 'X1000GEM'": 1,
#          " 'VC'": 9,
#          " 'BITGET'": 2,
#          " 'KAWA'": 4,
#          " 'STOCKMARKETNEWS'": 4,
#          " 'NFTS'": 891,
#          " 'BLOCKCHAIN'": 1944,
#          " 'ALPINE'": 3,
#          " 'APPLE'": 30,
#          " 'AR'": 52,
#          " '仮想通貨'": 234,
#          " 'COINMARKETCAP'": 47,
#          " 'BSV'": 7,
#          " 'REACTJS'": 5,
#          " 'SAFEMOON'": 4,
#          " 'DOLAR'": 61,
#          " 'REP'": 2,
#          " 'BILPCOIN'": 13,
#          " 'BUSINESSTIPS'": 4,
#          " 'USDCAD'": 1,
#          " 'INVEST'": 48,
#          " 'DISCORD'": 21,
#          " 'ドル円'": 5,
#          " 'PERSONALFINANCE'": 4,
#          " 'NFTSHILL'": 360,
#          " 'NFTARTWORKS'": 4,
#          " '馬來西亞'": 1,
#          " 'EMPLOYEEEXPERIENCE'": 1,
#          " 'ANIMAL'": 1,
#          " 'ALTCOIN'": 869,
#          " 'DAOS'": 4,
#          " 'MUSK'": 5,
#          " 'WHALEFIN'": 2,
#          " 'ECONOMIA'": 2,
#          " 'ENDEKS'": 12,
#          " 'BMSCH'": 2,
#          " 'STEEM'": 1,
#          " 'DOMAIN'": 15,
#          " 'TRADE'": 48,
#          " 'SISECAM'": 1,
#          " 'LIVE'": 13,
#          " 'AUSTRALIA'": 10,
#          " 'HDFCBANK'": 1,
#          " 'HECO'": 1,
#          " 'BLOKZINCIR'": 2,
#          " 'DAYTRADING'": 19,
#          " 'TECHNOLOGY'": 68,
#          " 'NAPOLI'": 2,
#          " 'ETHERNET'": 2,
#          " 'INNOVATI'": 5,
#          " 'XLM'": 58,
#          " 'ДОЛЛАР'": 7,
#          " 'OP'": 1,
#          " 'JAVA'": 3,
#          " 'IMAGAWA'": 2,
#          " 'BTCUSD'": 113,
#          " 'CRO'": 94,
#          " 'AUDUSD'": 4,
#          " 'GEWINNSPIELE'": 2,
#          " '為替介入'": 1,
#          " 'SOLANA'": 182,
#          " 'NFTCOLLECTIBLES'": 37,
#          " 'FED'": 28,
#          " '3DINTERNET'": 1,
#          " 'FREEMINT'": 120,
#          " 'MACHINELEARNING'": 38,
#          " 'RAREAPEPEYC'": 9,
#          " 'ANIMALS'": 1,
#          " 'FLOKI'": 29,
#          " 'CRYPTOART'": 99,
#          " 'RTARTBOOST'": 14,
#          " 'MACHINELEARNI'": 1,
#          " 'AVAX'": 225,
#          " 'KEEPERDAO'": 2,
#          " 'INFLACION'": 2,
#          " 'CELHA'": 3,
#          " 'FEDCHAIRPOWELLSPEAKS'": 1,
#          " 'OYYAT'": 2,
#          " 'AXS'": 9,
#          " 'ALTS'": 14,
#          " 'SOL'": 170,
#          " 'VITALIKBURTON'": 7,
#          " 'SAVINGS'": 1,
#          " 'COMMUNITY'": 16,
#          " 'BSC'": 339,
#          " 'EXCHANGE'": 113,
#          " 'AÇIKLAMA'": 1,
#          " 'TIKTOK'": 5,
#          " 'NFTGIVEAWAYS'": 70,
#          " 'INTRADAY'": 2,
#          " 'FANTOM'": 35,
#          " 'MACHINELEA'": 2,
#          " '熊市'": 2,
#          " 'KIBA'": 4,
#          " 'RBXS'": 178,
#          " 'USDC'": 148,
#          " 'STOCKMARKETINDIA'": 3,
#          " 'AIRMAX'": 4,
#          " 'FIFAWORLDCUP2022'": 7,
#          " 'ELON'": 8,
#          " 'HEALTHCARE'": 10,
#          " 'DC'": 4,
#          " 'FINTECH'": 136,
#          " 'CITY'": 2,
#          " 'ANGELINAJOLIEXPOOL'": 4,
#          " 'SPIN'": 5,
#          " 'GOOGLE'": 11,
#          " 'VR'": 57,
#          " 'KAS'": 1,
#          " 'GOALS'": 4,
#          " 'CRYPTOS'": 77,
#          " 'ステラ'": 3,
#          " 'БАНК'": 7,
#          " 'XEM'": 29,
#          " 'REAL'": 1,
#          " 'RSTATS'": 3,
#          " 'XRP'": 424,
#          " 'MACHINE'": 1,
#          " 'BTCUSDT'": 70,
#          " 'ANKR'": 1,
#          " 'CHARACTERDESIGN'": 1,
#          " 'HIVE'": 31,
#          " 'POLKADOT'": 10,
#          " 'MACHINEL'": 3,
#          " 'GBPJPY'": 5,
#          " 'FORYOU'": 2,
#          " 'CRYPTOMARKETS'": 10,
#          " 'MONEY'": 126,
#          " 'ARTIST'": 33,
#          " 'B'": 1,
#          " 'NFTDROPS'": 17,
#          " 'NFTCOLLECTOR'": 112,
#          " 'NFTDROP'": 308,
#          " 'GAMEFI'": 129,
#          " 'BIGDATA'": 68,
#          " 'CRYPTOARTIST'": 29,
#          " 'OPENSEANFTS'": 5,
#          " 'CRYPTOMARKET'": 299,
#          " 'GAMEDEV'": 19,
#          " 'SFM'": 2,
#          " 'TWITTER'": 39,
#          " 'TIANTIANKULLANDE'": 2,
#          " 'BIDEN'": 3,
#          " 'TRADINGOPPORTUNITY'": 1,
#          " 'KSTUR'": 2,
#          " 'NFTSALES'": 134,
#          " 'LSK'": 5,
#          " 'MEMECOIN'": 51,
#          " 'NFTARTIST'": 236,
#          " 'UNI'": 18,
#          " 'COLLECTIBLES'": 8,
#          " 'CURRENCY'": 52,
#          " 'BFREN'": 1,
#          " 'VPN'": 2,
#          " 'ALTIN'": 38,
#          " 'INDEX'": 16,
#          " 'NFTRECORDS'": 3,
#          " 'GEMINI'": 5,
#          " 'NFTMINT'": 3,
#          " '牛市'": 2,
#          " 'FEG'": 9,
#          " 'KRYPTO_NEW'": 1,
#          " 'BSE'": 3,
#          " 'AIRMAXST'": 4,
#          " 'RESISTANCE'": 7,
#          " 'SHIBARIUM'": 22,
#          " 'WBFF'": 1,
#          " 'WOMENINSTEM'": 2,
#          " 'BSCGEMS'": 44,
#          " 'WETH'": 3,
#          " 'INDUSTRY40'": 6,
#          " 'SLOT'": 4,
#          " 'NFTNEWS'": 57,
#          " 'STOCKS'": 52,
#          " 'KSM'": 41,
#          " 'DWD'": 2,
#          " 'FTT'": 96,
#          " 'КРИПТОВАЛЮТ'": 8,
#          " 'FCT'": 3,
#          " 'КАПИТАЛ'": 7,
#          " 'STMX'": 1,
#          " 'GEM'": 23,
#          " 'LINUX'": 3,
#          " 'NFTPROJECT'": 137,
#          " 'WALES'": 2,
#          " 'LINK'": 52,
#          " 'COINS'": 10,
#          " 'MOTIVATIONALQUOTES'": 3,
#          " 'TRAVISLAUNFT'": 2,
#          " '币圈'": 7,
#          " 'BTCS'": 25,
#          " 'FOLGEN'": 2,
#          " 'MANDALA'": 2,
#          " '金'": 1,
#          " 'NFTBUY'": 112,
#          " 'NFTARTGALLERY'": 10,
#          " 'DATASCIENCE'": 40,
#          " 'META'": 85,
#          " 'MARSMISSION'": 2,
#          " 'SPY'": 11,
#          " '1000XGEM'": 101,
#          " 'VIRTUALWORLD'": 6,
#          " 'NFTGIVEAWAY'": 72,
#          " 'OPENSEAARTISTS'": 1,
#          " 'SHIBAINU'": 20,
#          " 'CRYPTOCURENCY'": 145,
#          " 'SUSHISWAP'": 10,
#          " 'WHEX'": 1,
#          " 'ETHCLASSIC'": 14,
#          " 'TT'": 2,
#          " 'ITTFH'": 3,
#          " 'FUNDAMENTALNEWS'": 1,
#          " 'BRMEN'": 2,
#          " 'OPENSEA'": 163,
#          " 'TRON'": 62,
#          " 'JST'": 2,
#          " 'POCKETBETS'": 2,
#          " 'TECH'": 81,
#          " 'ALTCOINS'": 233,
#          " 'INSURTECH'": 10,
#          " 'GHANA'": 1,
#          " 'GK'": 1,
#          " 'NFTRENT'": 3,
#          " 'GENESISTRADING'": 2,
#          " 'NFTMINTALERT'": 2,
#          " '技術面'": 2,
#          " 'CHOICE'": 4,
#          " 'NFTCOLLECTION'": 53,
#          " 'BEACH'": 7,
#          " 'FONT'": 1,
#          " 'ETHMERGE'": 19,
#          " 'DATASCIENC'": 4,
#          " 'NSE'": 3,
#          " 'NIKEAIRMAX'": 4,
#          " 'SUPPORT'": 10,
#          " 'IFBB'": 1,
#          " 'REDDIT'": 2,
#          " 'AIRDROP'": 154,
#          " 'DIGITALART'": 98,
#          " '10ETH'": 1,
#          " 'LEADERSHIP'": 7,
#          " 'WITHFND'": 2,
#          " 'DIGITALCOLLECTIBLE'": 8,
#          " 'HOLOCHAIN'": 4,
#          " 'GBP'": 13,
#          " 'DOT'": 74,
#          " 'UPW'": 2,
#          " 'FTX'": 238,
#          " 'CYBERSECURITYTIPS'": 2,
#          " 'QTUM'": 11,
#          " 'ТОКЕН'": 7,
#          " 'THETRAITORS'": 1,
#          " 'SERVERLESS'": 1,
#          " 'MODEL'": 2,
#          " 'MAMAAWARDS'": 3,
#          " 'FIFAWORLDCUP'": 20,
#          " 'BUY'": 5,
#          " 'P2EGAMES'": 12,
#          " 'INSPIRATION'": 3,
#          " 'ART'": 168,
#          " 'FOREXMARKET'": 5,
#          " 'TREND'": 4,
#          " 'CRYPTOSIGNAL'": 1,
#          " '股票'": 1,
#          " 'BTCNEWS'": 37,
#          " 'XAUUSD'": 29,
#          " 'TACOTEAM'": 2,
#          " 'FX'": 57,
#          " 'KSA'": 9,
#          " 'NFTARTISTS'": 49,
#          " 'NEURALINK'": 183,
#          " 'PLANET'": 2,
#          " 'GOLD'": 133,
#          " '1000XGEMS'": 4,
#          " 'DREAMERFIFA2022'": 4,
#          " 'CHAINSAWMAN'": 8,
#          " 'OPENSEACOLLECTION'": 4,
#          " 'SAND'": 38,
#          " 'APPSTORE'": 2,
#          " 'AMBERGROUP'": 5,
#          " 'BURVA'": 3,
#          " 'INDICES'": 12,
#          " 'POW'": 7,
#          " 'MTRYO'": 2,
#          " 'NFTCOLLECTORS'": 160,
#          " 'SHIBA_INU'": 2,
#          " 'TRENDING'": 40,
#          " 'PLA'": 2,
#          " 'DECENTRALIZED'": 52,
#          " 'PUNKS'": 1,
#          " 'CRYPTOCURRENCIES'": 415,
#          " 'BEARMARKET'": 4,
#          " 'KONTR'": 1,
#          " 'CRYPTOWORLD'": 28,
#          " 'ZAMBIA'": 1,
#          " 'NFTRY'": 3,
#          " 'ALAMEDARESEARCH'": 13,
#          " '交易策略'": 2,
#          " 'MIRU'": 4,
#          " 'BLACKJACK'": 4,
#          " 'CG'": 69,
#          " 'LUNA2'": 5,
#          " 'PINETWORK'": 15,
#          " 'NIKE'": 4,
#          " 'FYP'": 2,
#          " 'CFG'": 4,
#          " 'R'": 2,
#          " 'UEFA'": 2,
#          " 'ARTWORK'": 13,
#          " 'VIRALINDO'": 4,
#          " 'MINING'": 86,
#          " 'WALLET'": 33,
#          " 'LAND'": 2,
#          " 'KRYPTOKUNST'": 8,
#          " 'EGITIM'": 4,
#          " 'EUR'": 14,
#          " 'KFC'": 3,
#          " 'GNS'": 1,
#          " '10X'": 2,
#          " 'BRISE'": 2,
#          " 'CYBERSEC'": 2,
#          " 'БИТКОЙН'": 8,
#          " 'LTC'": 229,
#          " 'БЛОКЧЕЙН'": 18,
#          " 'DIGITALETRANSFORMATION'": 1,
#          " 'PYTHON'": 60,
#          " 'ZBRUSH'": 2,
#          " 'VIRAL'": 13,
#          " 'QATARWORLDCUP2022'": 10,
#          " 'FLOW'": 19,
#          " 'PRICE'": 10,
#          " 'P2EGAMING'": 5,
#          " 'WALLETPHRASE'": 5,
#          " 'EXCHANGECRYPTO'": 3,
#          " 'WEB3ART'": 2,
#          " 'TRADER'": 55,
#          " 'VIRALPOST'": 3,
#          " 'VELO'": 1,
#          " '炒股'": 1,
#          " 'INVESTMENT'": 79,
#          " 'SCHALKE04'": 2,
#          " 'MAGIC'": 2,
#          " 'ゴールド'": 7,
#          " 'BINARY'": 3,
#          " 'NFTPROJECTS'": 138,
#          " 'INDIA'": 41,
#          " 'EVERYONE'": 3,
#          " 'SPORTSBETTINGPICKS'": 2,
#          " 'DOGECOIN'": 161,
#          " '100X'": 54,
#          " 'RPA'": 1,
#          " 'MMA2022'": 4,
#          " 'STAKING'": 25,
#          " 'SAITAMA'": 16,
#          " 'HERO'": 1,
#          " 'WASABIWALLET'": 6,
#          " 'COVID'": 8,
#          " 'NUHCM'": 3,
#          " 'DERAS'": 2,
#          " 'TREASURE'": 3,
#          " 'ຂ່າວຄິບໂຕ'": 1,
#          " 'APT'": 5,
#          " 'ARTOFTHEDAY'": 17,
#          " 'TICKER'": 3,
#          " 'POCKET'": 1,
#          " 'JAVASCRIPT'": 29,
#          " 'DIGITAL'": 28,
#          " 'CRYTOCURRENCY'": 1,
#          " 'ASGARI'": 9,
#          " 'FAIZKARARI'": 4,
#          " 'QATAR2022'": 25,
#          " 'CRYPTOCOM'": 13,
#          " 'KENYA'": 1,
#          " 'WHATSAPP'": 1,
#          " 'NFTU'": 3,
#          " 'GIVEAWAY'": 128,
#          " 'TURISMO'": 81,
#          " '比特幣價格'": 2,
#          " 'NFTBOOKS'": 4,
#          " 'POKER'": 4,
#          " 'NEAR'": 64,
#          " 'NFTARTWORK'": 23,
#          " 'COREDAO'": 1,
#          " 'DAYTRADER'": 4,
#          " 'FYPシ'": 1,
#          " 'SKU'": 4,
#          " 'ARTISTSONTWITTER'": 2,
#          " 'PORTO'": 2,
#          " 'MONSTER'": 2,
#          " 'IOTPL'": 4,
#          " 'DIGITALCURRENCY'": 12,
#          " 'SWAP'": 5,
#          " 'CRYPTO_CRASH'": 4,
#          " 'CEKILIS'": 5,
#          " 'NFTGAMING'": 10,
#          " 'MINECRAFT'": 3,
#          " 'SAITO'": 1,
#          " 'SALES'": 2,
#          " 'FUTURE'": 14,
#          " 'HEX'": 20,
#          " 'TECHTRENDS'": 2,
#          " 'HOWTO'": 3,
#          " 'CRYPTONEWSINDIA'": 2,
#          " 'БИТОК'": 8,
#          " 'ライトコイン'": 3,
#          " 'AZAMSWATI'": 1,
#          " 'IQ'": 1,
#          " 'TRANSFORMATIONNUMÉRIQUE'": 1,
#          " 'BIRD'": 2,
#          " 'TRENDINGNOW'": 6,
#          " 'FTM'": 173,
#          " 'AUTUMN'": 3,
#          " 'WEB3COMMUNITY'": 58,
#          " 'UTILITYNFT'": 6,
#          " 'FOREXLIFESTYLE'": 7,
#          " 'VIRALVIDEOS'": 3,
#          " 'BIKE'": 1,
#          " 'CAM'": 1,
#          " '股市'": 1,
#          " 'MONTANABLACK'": 2,
#          " 'ETHERUM'": 12,
#          " 'スキャ'": 1,
#          " 'STOCKMARKET'": 19,
#          " 'WEALTH'": 12,
#          " 'MINTYOURMOMENT'": 3,
#          " 'REDUCTION'": 3,
#          " 'STOCKMARKETS'": 11,
#          " 'LIEGE'": 3,
#          " 'ERC'": 100,
#          " 'CNFTCOMMUNNITY'": 24,
#          " 'ZENDAYA'": 1,
#          " 'OGCOLLECTIVE'": 6,
#          " 'UCL'": 2,
#          " 'FREEMINTNFT'": 2,
#          " 'CONTEMPORARYART'": 11,
#          " 'IA'": 2,
#          " 'GPAY'": 4,
#          " '100XGEM'": 44,
#          " 'DOGELONMARS'": 5,
#          " 'TRADINGPOST'": 2,
#          " 'CRYPTOCURRENCYMARKET'": 28,
#          " 'TODAY'": 3,
#          " 'ELECTRUM'": 6,
#          " 'RISHI'": 2,
#          " 'IZFAS'": 3,
#          " 'INVESTORS'": 3,
#          " 'KNFRT'": 2,
#          " 'DOGECOINS'": 14,
#          " 'OKB'": 7,
#          " 'CRYPTOFAM'": 2,
#          " 'ข่าวคริปโต'": 1,
#          " 'DKA'": 2,
#          " 'ICE'": 3,
#          " 'UNISWAP'": 19,
#          " 'CRYPTOC'": 6,
#          " 'THEMEFOREST'": 3,
#          " 'TENSORFLOW'": 6,
#          " 'PAWNER'": 1,
#          " 'LOWFEE'": 4,
#          " 'GAMING'": 48,
#          " 'FRONTEND'": 2,
#          " 'NIGERIA'": 2,
#          " 'TA'": 10,
#          " 'CYBERSECURITE'": 8,
#          " 'THETAVERSE'": 12,
#          " 'EURO'": 44,
#          " 'OPENSEANFT'": 51,
#          " 'SWINGTRADING'": 15,
#          " 'NFTEM'": 3,
#          " 'TORONTO'": 39,
#          " 'NFTBUYERS'": 4,
#          " '比特幣行情分析'": 2,
#          " 'ONLINECASINO'": 6,
#          " 'ATOM'": 24,
#          " 'POWELL'": 27,
#          " 'SYSTEMATICERROR'": 1,
#          " 'METAVERSENEWS'": 11,
#          " 'SENSEX'": 8,
#          " 'SILVER'": 51,
#          " 'QUAIDEV'": 4,
#          " 'FORYOUPAGE'": 1,
#          " 'DUBAI'": 28,
#          " '5G'": 5,
#          " 'NFTJAPAN'": 113,
#          " 'NFTMINTING'": 3,
#          " 'LAZIO'": 3,
#          " 'FREEGASFEE'": 4,
#          " 'R2E'": 11,
#          " 'PANCAKE'": 4,
#          " 'OPENSEAMARKET'": 2,
#          " 'DOKWON'": 11,
#          " 'SASAPOLYESTER'": 12,
#          " 'CRYTPOARTIST'": 3,
#          " 'SAPNAP'": 1,
#          " 'PHILOSOPHY'": 2,
#          " 'OUR'": 3,
#          " 'TECHTIPS'": 2,
#          " 'GAMES'": 13,
#          " 'CRYPTOINDIA'": 1,
#          " 'КРИПТА'": 8,
#          " 'JUSTICEFORSANJUSAMSON'": 1,
#          " 'CRYPTOVALUTE'": 1,
#          " 'PUNDIX'": 10,
#          " 'PUMP'": 2,
#          " 'TRANSFORMAÇÃODIGITAL'": 1,
#          " 'SECFTX'": 3,
#          " 'CODING'": 23,
#          " 'THETA'": 62,
#          " 'NINTENDO'": 2,
#          " 'POWR'": 4,
#          " 'WEB3GAMING'": 1,
#          " 'CRYPTOCOIN'": 49,
#          " 'CNFTCOMMUN'": 3,
#          " 'GAMEONLINE'": 1,
#          " 'ENTREPRENEURSHIP'": 4,
#          " 'EXPLOREPAGE'": 5,
#          " 'UTILITY'": 4,
#          " 'USDJPY'": 9,
#          " 'SPORTS'": 7,
#          " 'NEWJEANS'": 1,
#          " 'KNOSSI'": 2,
#          " 'スキャルピング'": 2,
#          " '1000X'": 115,
#          " 'GBPUSD'": 7,
#          " 'INVESTOR'": 38,
#          " 'FATHERSCUSTODY'": 1,
#          " 'PARRAINAGE'": 3,
#          " 'BOC'": 3,
#          " 'NFTDAY'": 4,
#          " 'GLOBALFIELDDAY'": 9,
#          " 'MONTREAL'": 3,
#          " 'CMC'": 137,
#          " 'CNFT'": 42,
#          " 'HUMANNATURE'": 1,
#          " 'ARTVISIONNFT'": 6,
#          " 'EVEROWN'": 4,
#          " 'STUDENTS'": 1,
#          " 'DISRUPTDEFI'": 9,
#          " 'BSCGEMALERT'": 11,
#          " 'STABLECOINS'": 22,
#          " 'SNX'": 4,
#          " 'ENTERTAINMENTNEWS'": 4,
#          " 'TRX'": 92,
#          " '音楽'": 4,
#          " 'TRADINGSIGNALS'": 38,
#          " 'BBC'": 11,
#          " 'TOPCRYPTONEWS'": 2,
#          " 'BAHRAIN'": 5,
#          " 'HUMPDAY'": 1,
#          " 'COINJARWALLET'": 6,
#          " 'RISHISUNAK'": 2,
#          " 'SODSN'": 3,
#          " 'CRYPTOARTWORK'": 2,
#          " 'KLGYO'": 2,
#          " 'ETSYSELLER'": 9,
#          " 'LITECOIN'": 56,
#          " 'HEXICANS'": 10,
#          " 'ETC'": 18,
#          " 'ລົງທຶນຄິບໂຕ'": 1,
#          " 'CATECOIN'": 5,
#          " 'ALTCOINSEASON'": 19,
#          " 'VALUEINVESTING'": 6,
#          " 'PLANB'": 6,
#          " 'SITETEMPLATES'": 3,
#          " 'TREASURY'": 1,
#          " 'BNBSMARTCHAIN'": 35,
#          " 'FULLSTACK'": 2,
#          " 'INNOVATION'": 40,
#          " 'CHART'": 5,
#          " 'CYBERSECURITY'": 46,
#          " 'OURCRYPTOGIVESBACK'": 4,
#          " 'USP'": 4,
#          " 'CRYPTOCRASH'": 74,
#          " 'EUROPE'": 13,
#          " 'AAVE'": 6,
#          " 'TECHNICALANALYSIS'": 25,
#          " 'DIGITALASSET'": 60,
#          " 'NFTC'": 3,
#          " 'TORNADO'": 2,
#          " 'VACATIONS'": 45,
#          " 'KRYPTOMARKT'": 1,
#          " 'POSSIBLE'": 3,
#          " 'TWOGEINU'": 1,
#          " '投資新手'": 2,
#          " 'WEBDEVELOPER'": 2,
#          " 'SLOTS'": 4,
#          " 'ASLAN'": 1,
#          " 'FOREX_DESTEK'": 2,
#          " 'WEITERHIN'": 1,
#          " 'IŞLEM'": 6,
#          " 'ETHICALIMPLICATION'": 1,
#          " 'METAVERSENFT'": 34,
#          " 'FUNNY'": 1,
#          " 'DIVRAMIS'": 4,
#          " 'APP'": 12,
#          " 'KICKS'": 4,
#          " 'WORLDCUP2022'": 27,
#          " 'QUAIDEVELOPER'": 3,
#          " 'SX5E'": 1,
#          " 'FUN'": 2,
#          " 'MTRG'": 4,
#          " 'SANTOS'": 2,
#          " 'POLYGONMATIC'": 4,
#          " 'PAY'": 2,
#          " 'AIRDROPS'": 123,
#          " 'CRYPTOEDUCATION'": 1,
#          " '1INCH'": 4,
#          " 'NFTMARKETPLACE'": 27,
#          " 'NFTKUNST'": 8,
#          " 'SISE'": 21,
#          " 'GLENNHAMMONDKY'": 1,
#          " 'JASMY'": 27,
#          " 'GYM'": 2,
#          " 'DECENTRALISATION'": 7,
#          " 'TECHNEWS'": 5,
#          " 'WINDOWS'": 5,
#          " 'CRYPTOININDIA'": 1,
#          " 'PROBLOCKCHAIN'": 8,
#          " 'IOST'": 6,
#          " 'GMFRENS'": 3,
#          " 'JHOPEXMAMA'": 10,
#          " 'BTCPRICE'": 38,
#          " 'GLM'": 4,
#          " 'WAX'": 3,
#          " 'CZBNB'": 19,
#          " 'TWIZZLER'": 2,
#          " 'PROGRAMMING'": 1,
#          " 'HALLOWEEN'": 2,
#          " 'CRONOS'": 4,
#          " 'JEWEL'": 3,
#          " 'RASHFORD'": 2,
#          " 'IOTA'": 6,
#          " 'PHOTOS'": 2,
#          " 'CBDC'": 42,
#          " 'CRYPTOTOKEN'": 22,
#          " 'METAWHALETHEMOO'": 8,
#          " 'FLOK'": 13,
#          " 'COLORS'": 2,
#          " 'COINDCX'": 1,
#          " 'KRIPTOPARA'": 61,
#          " 'STARKNET'": 5,
#          " 'REELS'": 3,
#          " 'SYSCOIN'": 20,
#          " 'ECOLOGY'": 1,
#          " 'PEAFDOVE'": 1,
#          " 'ET'": 2,
#          " 'HOUSINGMARKET'": 2,
#          " 'PET'": 1,
#          " 'BAYERNMÜNCHEN'": 2,
#          " 'FX勉強中'": 1,
#          " 'CHINA'": 30,
#          " 'SUBUTAI'": 1,
#          " 'BTCMINING'": 30,
#          " 'FATHERCUSTODY'": 1,
#          " 'NFTCRYPTO'": 112,
#          " 'RAIINMAKERAPP'": 3,
#          " 'THAILAND'": 2,
#          " 'CRYPTOCOMMUNITY'": 19,
#          " 'MENTALHEALTH'": 5,
#          " 'CARDANO'": 217,
#          " 'ANONYMOUS'": 2,
#          " 'MACP'": 7,
#          " 'QUÉBEC'": 3,
#          " 'JIMCARREY'": 1,
#          " 'FIXEDMATCH'": 2,
#          " 'PLAYTOEARNGAMES'": 15,
#          " 'WHICHCRYPTOCOINTOINVEST'": 11,
#          " 'EVERSWAP'": 7,
#          " 'AURORA'": 4,
#          " 'MYR'": 1,
#          " 'JTBD'": 1,
#          " 'STORY'": 5,
#          " 'SEINOTOCEX'": 3,
#          " 'TSLA'": 2,
#          " 'HEALTH'": 10,
#          " 'BULLISH'": 27,
#          " 'P2E'": 59,
#          " 'DEX'": 42,
#          " '音乐'": 14,
#          " 'ONLINETRADING'": 2,
#          " 'ブロックチェーン'": 6,
#          " 'SBFSCANDAL'": 2,
#          " 'ETHNICWEAR'": 4,
#          " 'XRPHOLDERS'": 2,
#          " 'HASHEUR'": 1,
#          " 'MYCELIUMWALLET'": 6,
#          " 'INGLATERRA'": 2,
#          " 'EDIP'": 3,
#          " 'STOCKSTOTRADE'": 1,
#          " 'ACSEL'": 2,
#          " 'PLUSMINUSCO'": 7,
#          " 'STELLUM'": 8,
#          " 'KRYPTO_NEWS'": 2,
#          " 'DOLARTL'": 3,
#          " 'ลงทุนคริปโต'": 1,
#          " 'SQUIDGROW'": 3,
#          " 'CRYPTOCONTEST'": 6,
#          " 'MINTING'": 6,
#          " 'MODELTHEME'": 3,
#          " 'ETHNEWS'": 2,
#          " '绿卡'": 2,
#          " 'TEST'": 4,
#          " 'QATAR2022ONMG'": 4,
#          " 'CHARITY'": 5,
#          " 'SASAMAĞDURLARI'": 10,
#          " 'DISCORDSERVERS'": 2,
#          " 'CR7NFT'": 1,
#          " 'SNM'": 4,
#          " 'US500'": 4,
#          " 'TDROP'": 12,
#          " 'POLYGONNFTS'": 3,
#          " 'UNIQUESERVICEPROVIDER'": 4,
#          " 'BTCPRICETODAY'": 3,
#          " 'BBTVI'": 4,
#          " 'CRYPTOCURRECY'": 58,
#          " 'NEWSRELEASE'": 2,
#          " 'BSCPITBULL'": 1,
#          " 'WTI'": 5,
#          " 'DYX'": 1,
#          " 'SUPPLYCHAINMANAGEMENT'": 1,
#          " 'SUSHI'": 9,
#          " 'DATAPROTECTION'": 7,
#          " 'NFTCPAIDPROMOTEAERIAL'": 3,
#          " 'ITALIA'": 3,
#          " 'BLOCKFI'": 45,
#          " 'IS'": 3,
#          " 'TWOGE'": 1,
#          " '幣安BNB'": 2,
#          " 'CUSTODIANSHIP'": 2,
#          " 'MÜGEANLI'": 1,
#          " 'EVERRISENFTSTAKINGLAB'": 7,
#          " 'TAGEN'": 1,
#          " 'NFTSHILLING'": 6,
#          " 'LUNAC'": 2,
#          " 'THINKBIG'": 6,
#          " 'PYHTON'": 1,
#          " 'MONOGRAM'": 2,
#          " 'WEB3PH'": 1,
#          " 'FARMING'": 21,
#          " 'PETRO'": 4,
#          " 'SNEAKARTIVIST'": 4,
#          " 'ONLINEEARNING'": 1,
#          " 'QUAICOMMUNITY'": 3,
#          " 'LICENSED'": 2,
#          " 'CLOUD'": 14,
#          " 'ATM'": 2,
#          " 'POLYGONNETWORK'": 8,
#          " 'IIOT'": 5,
#          " 'NFTCOLLECTIONS'": 27,
#          " 'PAYMENT'": 8,
#          " 'NFTFAMILY'": 1,
#          " 'WUSE'": 5,
#          " 'CRYPTOCURRENCYTRADING'": 1,
#          " 'GENESIS'": 14,
#          " 'PZEN'": 5,
#          " 'NFTCOMMMUNITY'": 35,
#          " 'NONFUNGIBLETOKEN'": 10,
#          " 'USTC'": 30,
#          " 'ILV'": 1,
#          " 'BTCMEMES'": 18,
#          " 'NEUTRAL'": 34,
#          " 'FAIL'": 4,
#          " 'ລົງທຶນ'": 5,
#          " 'MICROSTRATEGY'": 4,
#          " 'SEO'": 10,
#          " 'CRYPTOHINDI'": 1,
#          " 'UNFI'": 1,
#          " 'FRENS'": 3,
#          " 'NFTARTİSTS'": 3,
#          " 'CZ'": 13,
#          " 'RISE'": 7,
#          " 'ANALYTICS'": 21,
#          " 'GAMBLINGTWITTER'": 3,
#          " 'BLOCKCHAINGAMING'": 14,
#          " 'KNOWYOURZONO'": 18,
#          " 'METAWHALEWORLD'": 8,
#          " 'MEGAMILLIONS'": 1,
#          " 'RAILSTRIKE'": 2,
#          " 'PETROAPP'": 7,
#          " 'DATA'": 34,
#          " 'STANDWITHUKRAINE'": 2,
#          " 'DIGITALARTWORK'": 2,
#          " 'BTCTWITTER'": 11,
#          " '100XGEMS'": 44,
#          " 'KAZANÇ'": 1,
#          " 'FOREXSIGNALS'": 19,
#          " 'SHM'": 2,
#          " 'AUDIA6'": 3,
#          " 'REELSINSTAGRAM'": 3,
#          " 'WEB3DOM'": 1,
#          " 'PANCAKESWAP'": 4,
#          " 'HOUSING'": 2,
#          " 'WIMBERLEY'": 1,
#          " '区块链'": 5,
#          " 'URLAUB'": 2,
#          " 'SPIRITUAL'": 2,
#          " 'CL'": 4,
#          " 'FX初心者'": 6,
#          " 'CRYPTOCASINO'": 1,
#          " 'PYR'": 10,
#          " 'EURUSD'": 21,
#          " 'CUSTODY'": 2,
#          " 'AETERNALS'": 3,
#          " 'ビットコイン'": 75,
#          " 'ELECTRICVEHICLES'": 5,
#          " 'WWE'": 6,
#          " 'TEXANS'": 7,
#          " 'BLOCKCHAINTECHNOLOGY'": 53,
#          " 'REWARDS'": 6,
#          " 'CANADA'": 50,
#          " 'NEURAFLECTION'": 69,
#          " 'FOOTBALLBETS'": 2,
#          " 'NFTPROMOTION'": 14,
#          " 'LALAVERSE'": 5,
#          " 'PLAYTOEARN'": 29,
#          " 'WHICHCRYPTOBUYTODAY'": 11,
#          " 'ARBITRUM'": 32,
#          " 'INFINITEJOURNEYS'": 1,
#          " 'CHICKENRICE'": 1,
#          " 'FREE'": 40,
#          " 'TOKEN'": 37,
#          " 'GOOG'": 2,
#          " 'BLOCKCHAINDEVELOPER'": 3,
#          " 'MUSICA'": 14,
#          " 'KRIPTO'": 86,
#          " 'ME'": 2,
#          " 'السعودية'": 3,
#          " 'VIDEO'": 5,
#          " 'BAKC'": 11,
#          " 'SAMBANKMANFRIED'": 14,
#          " 'UAE'": 8,
#          " 'GME'": 1,
#          " 'BUSD'": 82,
#          " '為替'": 1,
#          ...})

# %%
len(final_count.keys())
# Out:
# 6507
